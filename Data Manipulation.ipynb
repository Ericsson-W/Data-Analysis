# %%
import csv
import pandas as pd
import numpy as np

# %%
Garage=pd.read_csv('Garage.csv')
Property=pd.read_csv('Property.csv')
Transaction=pd.read_csv('Transaction.csv')

# %%
#### Question 1

# %%
len(Property.columns)
# Out:
# 33

# %%
#### Question 2

# %%
Property.sort_values('LotArea',ascending = True).head(5)
# Out:
#         Id  LotArea Street  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 956    957     1300   Pave            6            6       1980          1980
# 1039  1040     1477   Pave            4            4       1970          1970
# 614    615     1491   Pave            4            6       1972          1972
# 489    490     1526   Pave            4            8       1970          2002
# 1449  1450     1533   Pave            5            7       1970          1970
#
#      RoofStyle  TotalBsmtSF Heating  ... Fireplaces FireplaceQu  PavedDrive  \
# 956      Gable          561    GasA  ...          1          TA           Y
# 1039     Gable          630    GasA  ...          0         NaN           Y
# 614      Gable          630    GasA  ...          0         NaN           Y
# 489      Gable          630    GasA  ...          0         NaN           Y
# 1449     Gable          630    GasA  ...          0         NaN           Y
#
# ...

# %%
print(Property.columns)
# Out:
# Index(['Id', 'LotArea', 'Street', 'OverallQual', 'OverallCond', 'YearBuilt',
#        'YearRemodAdd', 'RoofStyle', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', '1stFlrSF', '2ndFlrSF', 'GrLivArea', 'BsmtFullBath',
#        'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr',
#        'KitchenQual', 'TotRmsAbvGrd', 'Fireplaces', 'FireplaceQu',
#        'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'PoolQC'],
#       dtype='object')

# %%
print(Garage.columns)
# Out:
# Index(['Id', 'GarageType', 'GarageYrBlt', 'GarageCars', 'GarageArea',
#        'GarageQual', 'GarageCond'],
#       dtype='object')

# %%
#### Question 3

# %%
set(Property.Id)-set(Garage.Id)
# Out:
# {426, 801, 857, 984, 1136, 1167}

# %%
#### Question 4a

# %%
Garage['GarageType'].value_counts(ascending=False)
# Out:
# Attchd      862
# Detchd      364
# BuiltIn      88
# Detached     21
# Basment      14
# Attached     10
# CarPort       9
# 2Types        6
# Basement      5
# Name: GarageType, dtype: int64

# %%
sum(Garage.loc[Garage['GarageType'] == 'Detchd'].GarageArea)/len(Garage.loc[Garage['GarageType'] == 'Detchd'].GarageArea)
# Out:
# 428.22802197802196

# %%
#### Question 4b

# %%
Garage['GarageType'].isna().sum()
# Out:
# 81

# %%
#### Question 4c

# %%
Garage[Garage['GarageType'].isna()]
# Out:
#         Id GarageType  GarageYrBlt  GarageCars  GarageArea GarageQual  \
# 9     1039        NaN          NaN           0  472.980137        NaN
# 21     308        NaN          NaN           0  472.980137        NaN
# 67     496        NaN          NaN           0  472.980137        NaN
# 80     288        NaN          NaN           0  472.980137        NaN
# 94    1450        NaN          NaN           0  472.980137        NaN
# ...    ...        ...          ...         ...         ...        ...
# 1382   376        NaN          NaN           0  472.980137        NaN
# 1397    89        NaN          NaN           0  472.980137        NaN
# 1399   432        NaN          NaN           0  472.980137        NaN
# 1435  1454        NaN          NaN           0  472.980137        NaN
# 1447   211        NaN          NaN           0  472.980137        NaN
#
#      GarageCond
# 9           NaN
# 21          NaN
# 67          NaN
# 80          NaN
# 94          NaN
# ...         ...
# ...

# %%
Garage['GarageType']=Garage['GarageType'].fillna('Detchd')

# %%
sum(Garage.loc[Garage['GarageType'] == 'Detchd'].GarageArea)/len(Garage.loc[Garage['GarageType'] == 'Detchd'].GarageArea)
# Out:
# 436.3739125775287

# %%
#### Question 5

# %%
Property[(Property.OverallQual<5) | (Property.OverallCond<5)]
# Out:
#         Id  LotArea Street  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 17      18    10791   Pave            4            5       1967          1967
# 29      30     6324   Pave            4            6       1927          1950
# 30      31     8500   Pave            4            4       1920          1950
# 39      40     6040   Pave            4            5       1955          1955
# 48      49     4456   Pave            4            5       1920          2008
# ...    ...      ...    ...          ...          ...        ...           ...
# 1412  1413     7200   Pave            4            5       1949          1950
# 1416  1417    11340   Pave            4            6       1885          1950
# 1432  1433    10800   Pave            4            6       1927          2007
# 1436  1437     9000   Pave            4            6       1971          1971
# 1448  1449    11767   Pave            4            7       1910          2000
#
# ...

# %%
#### Question 6

# %%
frame=[Property,Garage]

# %%
Data=pd.merge(Property, Garage, how="left", on=['Id'])
Data=pd.merge(Data, Transaction, how="left", on=['Id'])
Data
# Out:
#         Id  LotArea Street  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0        1     8450   Pave            7            5       2003          2003
# 1        2     9600   Pave            6            8       1976          1976
# 2        3    11250   Pave            7            5       2001          2002
# 3        4     9550   Pave            7            5       1915          1970
# 4        5    14260   Pave            8            5       2000          2000
# ...    ...      ...    ...          ...          ...        ...           ...
# 1470  1456     7917   Pave            6            5       1999          2000
# 1471  1457    13175   Pave            6            6       1978          1988
# 1472  1458     9042   Pave            7            9       1941          2006
# 1473  1459     9717   Pave            5            6       1950          1996
# 1474  1460     9937   Pave            5            6       1965          1965
#
# ...

# %%
#### Question 7

# %%
x=sum(Data.loc[Data['HeatingQC'] == 'Ex'].SalePrice)/len(Data.loc[Data['HeatingQC'] == 'Ex'].SalePrice)
y=sum(Data.loc[Data['HeatingQC'] == 'Gd'].SalePrice)/len(Data.loc[Data['HeatingQC'] == 'Gd'].SalePrice)
x-y
# Out:
# 58532.30244808743

# %%
#### Question 8a

# %%
property_combined = pd.read_csv("Combined.csv")

# %%
property_combined
# Out:
#       LotArea  OverallQual  OverallCond  YearBuilt  TotalBsmtSF  1stFlrSF  \
# 0        8450            7            5       2003          856       856
# 1        9600            6            8       1976         1262      1262
# 2       11250            7            5       2001          920       920
# 3        9550            7            5       1915          756       961
# 4       14260            8            5       2000         1145      1145
# ...       ...          ...          ...        ...          ...       ...
# 1455     7917            6            5       1999          953       953
# 1456    13175            6            6       1978         1542      2073
# 1457     9042            7            9       1941         1152      1188
# 1458     9717            5            6       1950         1078      1078
# 1459     9937            5            6       1965         1256      1256
#
#       2ndFlrSF  GrLivArea  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# ...

# %%
property_combined.corr().OverallQual.sort_values(ascending=False)
# Out:
# OverallQual     1.000000
# GarageCars      0.600671
# GrLivArea       0.593007
# YearBuilt       0.572323
# GarageArea      0.562022
# TotalBsmtSF     0.537808
# 1stFlrSF        0.476224
# TotRmsAbvGrd    0.427452
# Fireplaces      0.396765
# 2ndFlrSF        0.295493
# LotArea         0.105806
# BedroomAbvGr    0.101676
# OverallCond    -0.091932
# KitchenAbvGr   -0.183882
# Name: OverallQual, dtype: float64

# %%
#### Question 8b

# %%
property_combined['Indoor_area']=property_combined['TotalBsmtSF']+property_combined['GrLivArea']+property_combined['1stFlrSF']+property_combined['2ndFlrSF']

# %%
property_combined['Age']=2022-property_combined['YearBuilt']

# %%
property_combined
# Out:
#       LotArea  OverallQual  OverallCond  YearBuilt  TotalBsmtSF  1stFlrSF  \
# 0        8450            7            5       2003          856       856
# 1        9600            6            8       1976         1262      1262
# 2       11250            7            5       2001          920       920
# 3        9550            7            5       1915          756       961
# 4       14260            8            5       2000         1145      1145
# ...       ...          ...          ...        ...          ...       ...
# 1455     7917            6            5       1999          953       953
# 1456    13175            6            6       1978         1542      2073
# 1457     9042            7            9       1941         1152      1188
# 1458     9717            5            6       1950         1078      1078
# 1459     9937            5            6       1965         1256      1256
#
#       2ndFlrSF  GrLivArea  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# ...

# %%
property_combined.corr().Indoor_area.sort_values(ascending=True)
# Out:
# Age            -0.298413
# OverallCond    -0.122519
# KitchenAbvGr    0.057084
# YearBuilt       0.298413
# LotArea         0.299103
# BedroomAbvGr    0.432387
# Fireplaces      0.486248
# 2ndFlrSF        0.492148
# GarageCars      0.525379
# GarageArea      0.543277
# OverallQual     0.658838
# TotalBsmtSF     0.703027
# 1stFlrSF        0.731139
# TotRmsAbvGrd    0.755151
# GrLivArea       0.952275
# Indoor_area     1.000000
# Name: Indoor_area, dtype: float64
